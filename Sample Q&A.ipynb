# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohitnith/Small-Data-Science-Projects/blob/main/Interview_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Whether string is anagram
s1 = 'qaz'
s2 = 'zaaq'
if sorted(s1)==sorted(s2):
  print("Nos. are Anagram")
else:
  print("Nos. are not Anagram")
# Out:
# Nos. are not Anagram

# %%
#whether no. in palindrome or not
s1 = '1221'
s2=s1[::-1]
if s1==s2:
  print("No is palindrome")
else:
  print("No is not palindrome")
# Out:
# No is palindrome

# %%
#if no is digit or not 
s1 = '122a1'
if s1.isdigit():
  print("No is Digit")
else:
  print("No is not digit")
# Out:
# No is not digit

# %%
#python program to convert lower case vowel to upper case
s1 = 'aweioudgsf adef'
def vowel_to_upper(x):
  a=list(x)
  vowels=['a','i','e','o','u']
  for i, j in enumerate(x):
    if j in vowels:
      a[i]=a[i].upper()
  return " ".join(a)

vowel_to_upper(s1)
# Out:
# 'A w E I O U d g s f   A d E f'

# %%
#python program to convert first word to upper case
s1 = 'i love python'
#def first_letter_upper(x):
a=list(s1)
for i, j in enumerate(a):
  if j== " ":
      a[i+1]=a[i+1].upper()
      a[0]=a[0].upper()
s2=" ".join(a)
s2
# Out:
# 'I   L o v e   P y t h o n'

# %%
#to remove vowels
s1 = 'aweioudgsf adef'
a=list(s1)
vowels=['a','i','e','o','u']
for i, j in enumerate(a):
  if j in vowels:
    a.pop(i)
s2=" ".join(a)
print(s2)
# Out:
# w i u d g s f   d f

# %%
#Python program to print highest frequency charcter in string
str ='aweaaasdddddwaaaaaaaaaaaaaaawwewwwwww'
a=set(str)
a=list(a)
count_dic={}
for j,i in enumerate(a):
  count_dic[i]=str.count(a[j])
count_dic=(sorted(count_dic.items(), key=lambda item: item[1], reverse=True))
print(count_dic[0][0])
# Out:
# a

# %%
# Binary search in python
import random 
list1=random.sample(range(1, 2000), 1000)
list1.sort()
def Binary_Search(n):
  lower_bound = 0
  upper_bound=len(list1)-1
  for i in range(len(list1)):
    mid = int((lower_bound + upper_bound)/2)
    if n == list1[mid]:
      print ("Found at index: ",mid)
      break
    elif n>list1[mid]:
      lower_bound= mid
    elif n<list1[mid]:
      upper_bound= mid
  else:
    print("No. not found")
n= int(input("Enter No. to be searched: "))
Binary_Search(n)
# Out:
# Enter No. to be searched: 2587
# No. not found

# %%
#Check if no. is Strong No.
# Strong No. 145 = 1!+ 4! + 5!
def fact(n):
  if n==0: return 0
  elif n==1: return 1
  else: return n* fact(n-2)

input=int(input("Enter No. to check: "))
str_input= str(input)
if input== fact(int(str_input[0]))+fact(int(str_input[1]))+ fact(int(str_input[2])):
  print("No is a strong No.")
else:
  print("No is not a strong No.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f33a21bf4dec> in <module>()
#       6   else: return n* fact(n-2)
#       7
# ----> 8 input=int(input("Enter No. to check: "))
#       9 str_input= str(input)
#      10 if input== fact(int(str_input[0]))+fact(int(str_input[1]))+ fact(int(str_input[2])):
#
# TypeError: 'int' object is not callable
